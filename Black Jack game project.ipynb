# %%
##code for blackjack game
import random
suits=("Hearts",'Diamonds','Spades','Diamonds')
ranks=("King",'Queen','Jack','Ace','Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten')
values={'King':10,'Queen':10,'Jack':10,'Ace':11,'Two':2,'Three':3,
        'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10}
Playing=True

# %%
##Definig Card class
class Card:
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
    def __str__(self):
        return self.suit+' of '+self.rank

# %%
##definig deck class
class Card:
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
    def __str__(self):
        return self.suit+' of '+self.rank
import random
suits=("Hearts",'Diamonds','Spades','Clubs')
ranks=("King",'Queen','Jack','Ace','Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten')
values={'King':10,'Queen':10,'Jack':10,'Ace':11,'Two':2,'Three':3,
        'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10}
Playing=True
class Deck:
    def __init__(self):
        self.deck=[]
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
    def __str__(self):
        cardindeck=''
        for card in self.deck:
            cardindeck+=card.__str__()+"\n"
        return 'The deck has '+ cardindeck
    def shuffle(self):
        random.shuffle(self.deck)
    def deal(self):
        single_card=self.deck.pop()
        return single_card
class Hand:
    def __init__(self):
        self.handcards=[]
        self.value=0
        self.aces=0
    def Addcard(self,card):
        self.handcards.append(card)
        self.value+=values[card.rank]
    def Adjustace(self):
        while self.value>21 and self.aces:
            self.value-=10
            self.aces-=1
class Chip():
    def __init__(self):
        self.totalchip=100
        self.bet=0
    def win_bet(self):
        self.totalchip+=self.bet
    def lose_bet(self):
        self.totalchip-=self.bet
##fuction to take bet amount as input from player
def take_bet(chips):
    while True:
        try:
            chips.bet=int(input("Enter your Bet Amount:"))
        except ValueError:
            print("Enter integer value only")
        else:
            if chips.bet>chips.totalchip:
                print("you cant bet more man {}".format(chips.total))
            else:
                break
##funtion to implement if player/dealer decide to take a card from deck
def Hit(deck,hand):
    hand.Addcard(deck.deal())
    hand.Adjustace()
def hitorstand(deck,hand):
    global Playing
    while True:
        i=input("Do you want to Hit or stand? enter 'h' or 's'")
        if i[0].lower()=='h':
            Hit(deck,player_hand)
        elif i[0].lower=='s':
            print("Player stands. Dealer is playing.")
            Playing = False
        else:
            print("Enter 'h' or 's'!!")
            continue
        break
def Show_some(dealer,player):
    print("Dealers card are: "+ dealer.handcards[0].__str__())
    for j in dealer.handcards[1:]:
         print("<Hidden Card>")
    print("PLayer cards are: ",*player.handcards,sep='\n')
def Show_all(dealer,player):
    print("Dealer card are: ",*dealer.handcards,sep='\n')
    print("Dealer card value: {}".format(dealer.value))
    print("Player cards are: ",*player.handcards,sep='\n')
    print("Player card value:{}".format(player.value))
##end of game scenarios
def playerbusts(player,dealer,chips):
    print("Player losed!!")
    chips.lose_bet()
def playerwins(player,dealer,chips):
    print("Player Won!!")
    chips.win_bet()
def dealerbusts(player,dealer,chips):
    print("Dealer losed!!")
    chips.win_bet()
def dealerwins(player,dealer,chips):
    print("Dealer won!!")
    chips.lose_bet()
def push(dealer,player):
    print("It's a tie")
while True:
    print('Welcome to BlackJack! Get as close to 21 as you can without going over!\n\
    Dealer hits until she reaches 17. Aces count as 1 or 11.')
    deck=Deck()
    deck.shuffle()
    player_hand=Hand()
    player_hand.Addcard(deck.deal())
    player_hand.Addcard(deck.deal())
    dealer_hand=Hand()
    dealer_hand.Addcard(deck.deal())
    dealer_hand.Addcard(deck.deal())
    player_chips=Chip()
    take_bet(player_chips)
    Show_some(dealer_hand,player_hand)
    while Playing:
        hitorstand(deck,player_hand)
        Show_some(dealer_hand,player_hand)
        if player_hand.value>21:
            playerbusts(player_hand,dealer_hand,player_chips)
            break
    if player_hand.value<=21:
        while dealer_hand.value<17:
            Hit(deck,dealer_hand)
        Show_all(dealer_hand,player_hand)
        if dealer_hand.value>21:
            dealerbusts(player_hand,dealer_hand,player_chips)
        elif player_hand.vale>dealer_hand.value:
            playerwins(player_hand,dealer_hand,player_chips)
        elif dealer_hand.value>player_hand.value:
            dealerwins(player_hand,dealer_hand,player_chips)
        else:
            push(dealer_hand,player_hand)
    print("\n Players winnin stand is at {}".format(player_chips.totalchip))
    new_game = input("Would you like to play another hand? Enter 'y' or 'n' ")
    
    if new_game[0].lower()=='y':
        playing=True
        continue
    else:
        print("Thanks for playing!")
        break

# %%
##defining a class for cards holded by a player or dealer
class Hand:
    def __init__(self):
        self.handcards=[]
        self.value=0
        self.aces=0
    def Addcard(self,card):
        self.handcards.append(card)
        self.value+=value[card.ranks]
    def Adjustace(self):
        while self.value>21 and self.aces:
            self.value-=10
            self.aces-=1

# %%
##defining a chip class
class Chip():
    def __init__(self):
        self.totalchip=100
        self.bet=0
    def win_bet(self):
        self.totalchip+=self.bet
    def lose_bet(self):
        self.totalchip-=self.bet

# %%
##fuction to take bet amount as input from player
def take_bet(chips):
    while True:
        try:
            chips.bet=int(input("Enter your Bet Amount:"))
        except ValueError:
            print("Enter integer value only")
        else:
            if chips.bet>chips.total:
                print("you cant bet more man {}".format(chips.total))
            else:
                break

# %%
##funtion to implement if player/dealer decide to take a card from deck
def Hit(deck,hand):
    hand.Addcard(deck.deal())
    hand.Adjustace()

# %%
def hitorstand(deck,hand):
    global Playing
    while True:
        i=input("Do you want to Hit or stand? enter 'h' or 's'")
        if i[0].lower()=='h':
            Hit(deck,hand)
        elif i[0].lower=='s':
            Playing = False
        else:
            print("Enter 'h' or 's'!!")
            continue
        break

# %%
def Show_some(dealer,player):
    print("Dealers card are: "+ dealer.handcards[0])
    for j in dealer.handcards[1:]:
         print("<Hidden Card>")
    print("PLayer cards are: ",*player.handcards,sep='\n')
def Show_all(dealer,player):
    print("Dealer card are: ",*dealer.handcards,sep='\n')
    print("Dealer card value: {}".format(dealer.value))
    print("Player cards are: ",*player.handcards,sep='\n')
    print("Player card value:{}".format(player.value))

# %%
##end of game scenarios
def playerbusts(player,dealer,chips):
    print("Player losed!!")
    chips.lose_bet()
def playerwins(player,dealer,chips):
    print("Player Won!!")
    chips.win_bet()
def dealerbusts(player,dealer,chips):
    print("Dealer losed!!")
    chips.win_bet()
def dealerwins(player,dealer,chips):
    print("Dealer won!!")
    chips.lose_bet()
def push(dealer,player):
    print("It's a tie")

# %%
##Game play
while True:
    print('Welcome to BlackJack! Get as close to 21 as you can without going over!\n\
    Dealer hits until she reaches 17. Aces count as 1 or 11.')
    deck=Deck()
    deck.shuffle()
    player_hand=Hand()
    player_hand.Addcard(deck.deal())
    player_hand.Addcard(deck.deal())
    dealer_hand=Hand()
    dealer_hand.Addcard(deck.deal())
    dealer_hand.Addcard(deck.deal())
    player_chips=Chips()
    take_bet(player_chips)
    Show_some(dealer_hand,player_hand)
    while Playing:
        hitorstand(deck,player_hand)
        Show_some(dealer_hand,player_hand)
        if player_hand.value>21:
            playerbusts(player_hand,dealer_hand,player_chips)
            break
    if player_hand.value<=21:
        while dealer_hand.value<17:
            Hit(deck,dealer_hand)
        Show_all(dealer_hand,player_hand)
        if dealer_hand.value>21:
            dealerbusts(player_hand,dealer_hand,player_chips)
        elif player_hand.vale>dealer_hand.value:
            playerwins(player_hand,dealer_hand,player_chips)
        elif dealer_hand.value>player_hand.value:
            dealerwins(player_hand,dealer_hand,player_chips)
        else:
            push(dealer_hand,player_hand)
    print("\n Players winnin stand is at {}".format(player_chips.total))
    new_game = input("Would you like to play another hand? Enter 'y' or 'n' ")
    
    if new_game[0].lower()=='y':
        playing=True
        continue
    else:
        print("Thanks for playing!")
        break
# Out:
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c05da8ea1fa2> in <module>
#       3     print('Welcome to BlackJack! Get as close to 21 as you can without going over!\n\
#       4     Dealer hits until she reaches 17. Aces count as 1 or 11.')
# ----> 5     deck=Deck()
#       6     deck.shuffle()
#       7     player_hand=Hand()
#
# NameError: name 'Deck' is not defined
